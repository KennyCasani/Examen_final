# %%
#primero llamo a todos los paquetes a utilizar para hacer el web scraping 
import re 
import requests 
import pandas as pd 
from bs4 import BeautifulSoup as b 

#1er paso
url="https://tesis.pucp.edu.pe/repositorio/"   # guardo al dirección ulink rl en url 
html=requests.get(url)                              # pido acceso para poder leer el contenido de la página 
content=html.content
soup=b(content,"lxml")      
link = soup.find_all('a', text='3. Licenciatura')
link = link[0]
href = link['href']
#2do paso
url="https://tesis.pucp.edu.pe/repositorio/handle/20.500.12404/3"   # guardo al dirección ulink rl en url 
html=requests.get(url)                              # pido acceso para poder leer el contenido de la página 
content=html.content
soup=b(content,"lxml")      
link = soup.find_all('a', text='Facultad de Ciencias e Ingeniería')
link = link[0]
href = link['href']
#3er paso
url="https://tesis.pucp.edu.pe:/repositorio/handle/20.500.12404/7"   # guardo al dirección ulink rl en url 
html=requests.get(url)                              # pido acceso para poder leer el contenido de la página 
content=html.content
soup=b(content,"lxml")      
link = soup.find_all('a', text='Ingeniería Informática')
link = link[0]
href = link['href']
#4to paso
lista=[]
url="https://tesis.pucp.edu.pe:/repositorio/handle/20.500.12404/14"# guardo al dirección ulink rl en url 
html=requests.get(url)                              # pido acceso para poder leer el contenido de la página 
content=html.content                                # accedo al contenido de la página 
soup=b(content,"lxml")                      # con este comando puedo obtener una mejor visualizaciónn del contenido de la página                               
data=soup.find_all(class_="thumbnail artifact-preview")
for linea in data:
    link=linea.find("a")
    links="https://tesis.pucp.edu.pe:"+link.get("href")
    
    lista.append(links)
#print(lista)

listatesis = [1, 2, 4]
lista3 = []

for i, element in enumerate(lista):
    if i in listatesis:
        lista3.append(element)
print(lista3)

# %%
#tesis 1
url="https://tesis.pucp.edu.pe:/repositorio/handle/20.500.12404/23555"
html=requests.get(url)
content=html.content
soup=b(content,"lxml")
data=soup.find("div",class_="simple-item-view-show-full item-page-field-wrapper table")
link=data.find("a")
print("https://tesis.pucp.edu.pe:"+ link["href"]) 
#código para extraer el contenido de la página
url="https://tesis.pucp.edu.pe:/repositorio/handle/20.500.12404/23555?show=full"
html=requests.get(url)
content=html.content
soup=b(content,"lxml")
data=soup.find(class_="ds-static-div primary")
info=data.find_all(class_="word-break")
for linea in info:
    contenido=linea.text
#extraemos el nombre de la universidad
url="https://tesis.pucp.edu.pe:/repositorio/handle/20.500.12404/23555?show=full"
html=requests.get(url)#hacemos una petición a la pagina web apra escrapearla
soup=b(content,"lxml")
data=soup.find(class_="ds-static-div primary")#extraemos las clases requeridas
universidad1=data.find_all(class_="word-break")[9].text
print("LA UNIVERSIDAD ES : " ,universidad)

#extraemos el título de la tesis
url="https://tesis.pucp.edu.pe:/repositorio/handle/20.500.12404/23555?show=full"
html=requests.get(url)#hacemos una petición a la pagina web apra escrapearla
content=html.content#extraemos todo el contenido de la página
soup=b(content,"lxml")
data=soup.find(class_="ds-static-div primary")#extraemos las clases requeridas
titulo1=data.find_all(class_="word-break")[16].text
print("EL TÍTULO ES :" ,titulo)


#extraemos el nombre del tesista
url="https://tesis.pucp.edu.pe:/repositorio/handle/20.500.12404/23555?show=full"
html=requests.get(url)#hacemos una petición a la pagina web apra escrapearla
content=html.content#extraemos todo el contenido de la página
soup=b(content,"lxml")
data=soup.find(class_="ds-static-div primary")#extraemos las clases requeridas
nombre_tesista1=data.find_all(class_="word-break")[1].text
print("EL NORMBRE ES :" ,nombre_tesista)


#se realiza para obtener el grado de.........
url="https://tesis.pucp.edu.pe:/repositorio/handle/20.500.12404/23555?show=full"
html=requests.get(url)#hacemos una petición a la pagina web apra escrapearla
content=html.content#extraemos todo el contenido de la página
soup=b(content,"lxml")
#extraemos las clases requeridas
data=soup.find(class_="ds-static-div primary")
grado1=data.find_all(class_="word-break")[18].text
print("EL GRADO OBTENIDO ES :" ,grado)

#extraemos la carrera del tesista
#guardamos la direccion web  en url
url="https://tesis.pucp.edu.pe:/repositorio/handle/20.500.12404/23555?show=full"
#hacemos una petición a la pagina web apra escrapearla
html=requests.get(url)
#extraemos todo el contenido de la página
content=html.content
soup=b(content,"lxml")
#extraemos las clases requeridas
data=soup.find(class_="ds-static-div primary")
profesion1=data.find_all(class_="word-break")[21].text
print("LA PROFESION DEL TESISTA ES :" ,profesion)


#extraemos al asesor del tesista
#guardamos la direccion web  en url
url="https://tesis.pucp.edu.pe:/repositorio/handle/20.500.12404/23555?show=full"
#hacemos una petición a la pagina web apra escrapearla
html=requests.get(url)
#extraemos todo el contenido de la página
content=html.content
soup=b(content,"lxml")
#extraemos las clases requerida
data=soup.find(class_="ds-static-div primary")
asesor1=data.find_all(class_="word-break")[0].text
print("EL NOMBRE DEL ASESOR ES :" ,asesor)


#estraemos el resumen dela tesis
#guardamos la direccion web  en url
url="https://tesis.pucp.edu.pe:/repositorio/handle/20.500.12404/23555?show=full"
#hacemos una petición a la pagina web apra escrapearla
html=requests.get(url)
#extraemos todo el contenido de la págin
content=html.content
soup=b(content,"lxml")
#extraemos las clases requeridas
data=soup.find(class_="ds-static-div primary")
resumen1=data.find_all(class_="word-break")[7].text
print("EL RESUMEN ES : " ,resumen)


#obtenemos el año de la tesis
#guardamos la direccion web  en url
url="https://tesis.pucp.edu.pe:/repositorio/handle/20.500.12404/23555?show=full"
#hacemos una petición a la pagina web apra escrapearla
html=requests.get(url)
#extraemos todo el contenido de la págin
content=html.content
soup=b(content,"lxml")
#extraemos las clases requerida
data=soup.find(class_="ds-static-div primary")
fecha_emitida1=data.find_all(class_="word-break")[4].text
print("LA FECHA DE LA TESIS : " ,fecha_emitida)

# %%
#tesis 2
url="https://tesis.pucp.edu.pe:/repositorio/handle/20.500.12404/23549"
html=requests.get(url)
content=html.content
soup=b(content,"lxml")
data=soup.find("div",class_="simple-item-view-show-full item-page-field-wrapper table")
link=data.find("a")
print("https://tesis.pucp.edu.pe:"+ link["href"]) 


#código para extraer el contenido de la página
url="https://tesis.pucp.edu.pe:/repositorio/handle/20.500.12404/23549?show=full"
html=requests.get(url)
content=html.content
soup=b(content,"lxml")
data=soup.find(class_="ds-static-div primary")
info=data.find_all(class_="word-break")
for linea in info:
    contenido=linea.text


#extraemos el nombre de la universidad
url="https://tesis.pucp.edu.pe:/repositorio/handle/20.500.12404/23549?show=full"
html=requests.get(url)#hacemos una petición a la pagina web apra escrapearla
soup=b(content,"lxml")
data=soup.find(class_="ds-static-div primary")#extraemos las clases requeridas
universidad2=data.find_all(class_="word-break")[9].text
print("LA UNIVERSIDAD ES : " ,universidad)


#extraemos el título de la tesis
url="https://tesis.pucp.edu.pe:/repositorio/handle/20.500.12404/23549?show=full"
html=requests.get(url)#hacemos una petición a la pagina web apra escrapearla
content=html.content#extraemos todo el contenido de la página
soup=b(content,"lxml")
data=soup.find(class_="ds-static-div primary")#extraemos las clases requeridas
titulo2=data.find_all(class_="word-break")[16].text
print("EL TÍTULO ES :" ,titulo)


#extraemos el nombre del tesista
url="https://tesis.pucp.edu.pe:/repositorio/handle/20.500.12404/23549?show=full"
html=requests.get(url)#hacemos una petición a la pagina web apra escrapearla
content=html.content#extraemos todo el contenido de la página
soup=b(content,"lxml")
data=soup.find(class_="ds-static-div primary")#extraemos las clases requeridas
nombre_tesista2=data.find_all(class_="word-break")[1].text
print("EL NORMBRE ES :" ,nombre_tesista)


#se realiza para obtener el grado de.........
url="https://tesis.pucp.edu.pe:/repositorio/handle/20.500.12404/23549?show=full"
html=requests.get(url)#hacemos una petición a la pagina web apra escrapearla
content=html.content#extraemos todo el contenido de la página
soup=b(content,"lxml")
#extraemos las clases requeridas
data=soup.find(class_="ds-static-div primary")
grado2=data.find_all(class_="word-break")[18].text
print("EL GRADO OBTENIDO ES :" ,grado)


#extraemos la carrera del tesista
url="https://tesis.pucp.edu.pe:/repositorio/handle/20.500.12404/23549?show=full"
#hacemos una petición a la pagina web apra escrapearla
html=requests.get(url)
#extraemos todo el contenido de la página
content=html.content
soup=b(content,"lxml")
#extraemos las clases requeridas
data=soup.find(class_="ds-static-div primary")
profesion2=data.find_all(class_="word-break")[21].text
print("LA PROFESION DEL TESISTA ES :" ,profesion)


#extraemos al asesor del tesista
url="https://tesis.pucp.edu.pe:/repositorio/handle/20.500.12404/23549?show=full"
#hacemos una petición a la pagina web apra escrapearla
html=requests.get(url)
#extraemos todo el contenido de la página
content=html.content
soup=b(content,"lxml")
#extraemos las clases requerida
data=soup.find(class_="ds-static-div primary")
asesor2=data.find_all(class_="word-break")[0].text
print("EL NOMBRE DEL ASESOR ES :" ,asesor)


#estraemos el resumen dela tesis
url="https://tesis.pucp.edu.pe:/repositorio/handle/20.500.12404/23549?show=full"
#hacemos una petición a la pagina web apra escrapearla
html=requests.get(url)
#extraemos todo el contenido de la págin
content=html.content
soup=b(content,"lxml")
#extraemos las clases requeridas
data=soup.find(class_="ds-static-div primary")
resumen2=data.find_all(class_="word-break")[7].text
print("EL RESUMEN ES : " ,resumen)


#obtenemos el año de la tesis
url="https://tesis.pucp.edu.pe:/repositorio/handle/20.500.12404/23549?show=full"
#hacemos una petición a la pagina web apra escrapearla
html=requests.get(url)
#extraemos todo el contenido de la págin
content=html.content
soup=b(content,"lxml")
#extraemos las clases requerida
data=soup.find(class_="ds-static-div primary")
fecha_emitida2=data.find_all(class_="word-break")[4].text
print("LA FECHA DE LA TESIS : " ,fecha_emitida)

# %%
#tesis 3
url="https://tesis.pucp.edu.pe:/repositorio/handle/20.500.12404/23266"
html=requests.get(url)
content=html.content
soup=b(content,"lxml")
data=soup.find("div",class_="simple-item-view-show-full item-page-field-wrapper table")
link=data.find("a")
print("https://tesis.pucp.edu.pe:"+ link["href"]) 


#código para extraer el contenido de la página
url="https://tesis.pucp.edu.pe:/repositorio/handle/20.500.12404/23266?show=full"
html=requests.get(url)
content=html.content
soup=b(content,"lxml")
data=soup.find(class_="ds-static-div primary")
info=data.find_all(class_="word-break")
for linea in info:
    contenido=linea.text


#extraemos el nombre de la universidad
url="https://tesis.pucp.edu.pe:/repositorio/handle/20.500.12404/23266?show=full"
html=requests.get(url)#hacemos una petición a la pagina web apra escrapearla
soup=b(content,"lxml")
data=soup.find(class_="ds-static-div primary")#extraemos las clases requeridas
universidad3=data.find_all(class_="word-break")[9].text
print("LA UNIVERSIDAD ES : " ,universidad)

#extraemos el título de la tesis
url="https://tesis.pucp.edu.pe:/repositorio/handle/20.500.12404/23266?show=full"
html=requests.get(url)#hacemos una petición a la pagina web apra escrapearla
content=html.content#extraemos todo el contenido de la página
soup=b(content,"lxml")
data=soup.find(class_="ds-static-div primary")#extraemos las clases requeridas
titulo3=data.find_all(class_="word-break")[16].text
print("EL TÍTULO ES :" ,titulo)


#extraemos el nombre del tesista
url="https://tesis.pucp.edu.pe:/repositorio/handle/20.500.12404/23266?show=full"
html=requests.get(url)#hacemos una petición a la pagina web apra escrapearla
content=html.content#extraemos todo el contenido de la página
soup=b(content,"lxml")
data=soup.find(class_="ds-static-div primary")#extraemos las clases requeridas
nombre_tesista3=data.find_all(class_="word-break")[1].text
print("EL NORMBRE ES :" ,nombre_tesista)


#se realiza para obtener el grado de.........
url="https://tesis.pucp.edu.pe:/repositorio/handle/20.500.12404/23266?show=full"
html=requests.get(url)#hacemos una petición a la pagina web apra escrapearla
content=html.content#extraemos todo el contenido de la página
soup=b(content,"lxml")
#extraemos las clases requeridas
data=soup.find(class_="ds-static-div primary")
grado3=data.find_all(class_="word-break")[18].text
print("EL GRADO OBTENIDO ES :" ,grado)

#extraemos la carrera del tesista
#guardamos la direccion web  en url
url="https://tesis.pucp.edu.pe:/repositorio/handle/20.500.12404/23266?show=full"
#hacemos una petición a la pagina web apra escrapearla
html=requests.get(url)
#extraemos todo el contenido de la página
content=html.content
soup=b(content,"lxml")
#extraemos las clases requeridas
data=soup.find(class_="ds-static-div primary")
profesion3=data.find_all(class_="word-break")[21].text
print("LA PROFESION DEL TESISTA ES :" ,profesion)


#extraemos al asesor del tesista
#guardamos la direccion web  en url
url="https://tesis.pucp.edu.pe:/repositorio/handle/20.500.12404/23266?show=full"
#hacemos una petición a la pagina web apra escrapearla
html=requests.get(url)
#extraemos todo el contenido de la página
content=html.content
soup=b(content,"lxml")
#extraemos las clases requerida
data=soup.find(class_="ds-static-div primary")
asesor3=data.find_all(class_="word-break")[0].text
print("EL NOMBRE DEL ASESOR ES :" ,asesor)


#estraemos el resumen dela tesis
#guardamos la direccion web  en url
url="https://tesis.pucp.edu.pe:/repositorio/handle/20.500.12404/23266?show=full"
#hacemos una petición a la pagina web apra escrapearla
html=requests.get(url)
#extraemos todo el contenido de la págin
content=html.content
soup=b(content,"lxml")
#extraemos las clases requeridas
data=soup.find(class_="ds-static-div primary")
resumen3=data.find_all(class_="word-break")[7].text
print("EL RESUMEN ES : " ,resumen)


#obtenemos el año de la tesis
#guardamos la direccion web  en url
url="https://tesis.pucp.edu.pe:/repositorio/handle/20.500.12404/23266?show=full"
#hacemos una petición a la pagina web apra escrapearla
html=requests.get(url)
#extraemos todo el contenido de la págin
content=html.content
soup=b(content,"lxml")
#extraemos las clases requerida
data=soup.find(class_="ds-static-div primary")
fecha_emitida3=data.find_all(class_="word-break")[4].text
print("LA FECHA DE LA TESIS : " ,fecha_emitida)

# %%
#creamos un dataframe 
df=pd.DataFrame()
#insertamos:
#insertamos estructura del informe
df['Estructura']= ["Universidad","Título","Nombre del tesista","Grado","profesion","Asesor","Resumen","Fecha emitida"]
#insertamos los datos extraidos de la tesis 1
df['Primera tesis']=[universidad1,titulo1,nombre_tesista1,grado1,profesion1,asesor1,resumen1,fecha_emitida1]
#insertamos los datos extraidos de la tesis 2
df['Segunda tesis']=[universidad2,titulo2,nombre_tesista2,grado2,profesion2,asesor2,resumen2,fecha_emitida2]
#insertamos los datos extraidos de la tesis 3
df['Tercera tesis']=[universidad3,titulo3,nombre_tesista3,grado3,profesion3,asesor3,resumen3,fecha_emitida3]
df
